# %%
q="this is My First Python programming class and i am learNING python string and its function"

# %%
q[0:300:4]
# Out:
# 't Mi hpricsdaeIpotgdsno'

# %%
q[::-1]
# Out:
# 'noitcnuf sti dna gnirts nohtyp GNINrael ma i dna ssalc gnimmargorp nohtyP tsriF yM si siht'

# %%
q=q.upper()

# %%
q
# Out:
# 'THIS IS MY FIRST PYTHON PROGRAMMING CLASS AND I AM LEARNING PYTHON STRING AND ITS FUNCTION'

# %%
q.split(" ")
# Out:
# ['THIS',
#  'IS',
#  'MY',
#  'FIRST',
#  'PYTHON',
#  'PROGRAMMING',
#  'CLASS',
#  'AND',
#  'I',
#  'AM',
#  'LEARNING',
#  'PYTHON',
#  'STRING',
#  'AND',
#  'ITS',
#  'FUNCTION']

# %%
q=q.lower()

# %%
q
# Out:
# 'this is my first python programming class and i am learning python string and its function'

# %%
q.capitalize()
# Out:
# 'This is my first python programming class and i am learning python string and its function'

# %%
q.title()
# Out:
# 'This Is My First Python Programming Class And I Am Learning Python String And Its Function'

# %%
w="asas55465435"

# %%
w.isalnum()
# Out:
# True

# %%
e="sdasda"

# %%
e.isalpha()
# Out:
# True

# %%
r="how\tare\tyou"

# %%
r.expandtabs()
# Out:
# 'how     are     you'

# %%
t="   Climate is good   "

# %%
t
# Out:
# '   Climate is good   '

# %%
t.strip()
# Out:
# 'Climate is good'

# %%
t.lstrip()
# Out:
# 'Climate is good   '

# %%
t.rstrip()
# Out:
# '   Climate is good'

# %%
y="Harikaran"

# %%
y.replace("a","i")
# Out:
# 'Hirikirin'

# %%
y.center(50,"9")
# Out:
# '99999999999999999999Harikaran999999999999999999999'

# %% [markdown]
# String center definition:Return a centered string of length width.

# %% [markdown]
# Interpreter:Reads one statement at a time  gives output or error.Is is a slow process.Errors can be rectified then and there

# %% [markdown]
# Compiler:Reads or scans the whole program and gives the output or error.It is a fast process.Error can only be rectified after running of full program.

# %% [markdown]
# Python:Python is a interpretor.As the program can be read line by line and executed with the help of pyhthon virtual machine then and there with either error or output.

# %% [markdown]
# Use Case of Python:
# 1:Application development in Computer
# 2.Web Application development
# 3.Game development
# 4.Machine learning
# 5.Data Ananlysis
